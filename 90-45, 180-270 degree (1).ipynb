# %%
from PIL import Image

#read the image
im = Image.open("C:/Users/User/Downloads/dog g.jfif")

#rotate image
angle = 45
out = im.rotate(angle)
out.save('C:/Users/User/Downloads/dog g.jfif')

# %%
from PIL import Image

#read the image
im = Image.open("C:/Users/User/Downloads/dog g.jfif")

#rotate image
angle = 45
out = im.rotate(angle, expand=True)
out.save('rotate-output.jfif')

# %%
# import the Python Image 
# processing Library
from PIL import Image
  
# Giving The Original image Directory 
# Specified
Original_Image = Image.open("C:/Users/User/Downloads/dog g.jfif")
  
# Rotate Image By 180 Degree
rotated_image1 = Original_Image.rotate(180)
  
# This is Alternative Syntax To Rotate 
# The Image
rotated_image2 = Original_Image.transpose(Image.ROTATE_90)
  
# This Will Rotate Image By 60 Degree
rotated_image3 = Original_Image.rotate(60)
  
rotated_image1.show()
rotated_image2.show()
rotated_image3.show()

# %%
# import OS module
import os
 
# Get the list of all files and directories
path="C:/Users/User/Downloads"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
# prints all files
print(dir_list)
# Out:
# Files and directories in ' C:/Users/User/Downloads ' :
# ...

# %%
# import the modules
import os
from os import listdir
 
# get the path/directory
folder_dir = "C:/Users/User/Downloads"


for images in os.listdir(folder_dir):
 
    # check if the image ends with png
    if (images.endswith(".png")):
        print(images)
# Out:
# background.png
# crop.png
# dice1.png
# Football_(soccer_ball).png
# images.png
# img.png
# img1.png
# imgsong.png
# key.png
# logo.png
# messageicon.png
# noisy.png
# oo.png
# rx1.png
# shr.png
# shreya.png
# xx.png

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("dog Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
 
image = mpimg.imread("C:/Users/User/Downloads/dog g.jfif")
plt.imshow(image)
plt.show()

# %%
# Importing Image class from PIL module
from PIL import Image
 
# Opens a image in RGB mode
im = Image.open(r"C:/Users/User/Downloads/dog g.jfif")
 
# Size of the image in pixels (size of original image)
# (This is not mandatory)
width, height = im.size
 
# Setting the points for cropped image
left = 6
top = height / 4
right = 174
bottom = 3 * height / 4
 
# Cropped image of above dimension
# (It will not change original image)
im1 = im.crop((left, top, right, bottom))
newsize = (200, 200)
im1 = im1.resize(newsize)
# Shows the image in image viewer
im1.show()

# %%
# import the modules
import os
from os import listdir
 
# get the path/directory

folder_dir = "C:/Users/User/Downloads"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png
    if (images.endswith(".png")):
        print(images)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12572/3573665039.py in <module>
#       4
#       5 # get the path/directory
# ----> 6 im = Image.open(r"C:/Users/User/Downloads")
#       7
#       8 folder_dir = "C:/Users/User/Downloads"
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/User/Downloads'

# %%
.
